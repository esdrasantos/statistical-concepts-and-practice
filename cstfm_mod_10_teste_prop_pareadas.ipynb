# %% [markdown]
# <a href="https://colab.research.google.com/github/esdrasantos/statistical-concepts-and-practice/blob/main/cstfm_mod_10_teste_prop_pareadas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Teste de McNemar para proporções pareadas

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np

# %%
tabela = np.array([[50,10],[15,25]])
tabela
# Out:
# array([[50, 10],
#        [15, 25]])

# %%
# Tabela de contingência

from statsmodels.stats.contingency_tables import mcnemar

teste = mcnemar(tabela)

print(teste)
# Out:
# pvalue      0.42435622215270996
# statistic   10.0

# %%
alfa = 0.05

if teste.pvalue > alfa:
  print('Não rejeitamos a hipótese nula')
  print('Logo as proporções são estatisticamente iguais')
else:
  print('Rejeitamos a hipótese nula')
  print('Logo as proporções são diferentes')
# Out:
# Não rejeitamos a hipótese nula
# Logo as proporções são estatisticamente iguais
