# %% [markdown]
# <a href="https://colab.research.google.com/github/esdrasantos/statistical-concepts-and-practice/blob/main/cstfm_teste_wilcoxon_1_amostra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
retorno_invest = pd.read_excel('/content/drive/MyDrive/Curso de Estatística 2.0/Arquivos Excel/Dados3_CursoEstatistica.xlsx', sheet_name=4)

retorno_invest
# Out:
#    Anos  Metais  Renda
# 0  2000   -7.34   4.07
# 1  2001   18.33   6.52
# 2  2002   33.35   9.38
# 3  2003   59.45  18.62
# 4  2004    8.09   9.44
# 5  2005   43.79   3.12
# 6  2006   34.30   8.15
# 7  2007   36.13   5.44
# 8  2008  -56.02 -11.37
# 9  2009   76.46  31.77

# %% [markdown]
# A mediana do retorno de Metais é maior do que 5%?
#
# Ho: m <= 5\
# Ha: m > 5

# %%
from scipy.stats import wilcoxon

# Teste para 1 Amostra

# Valor de Referencia (mediana esperada)

mediana = 5

stat, p = wilcoxon(retorno_invest['Metais'] - mediana, alternative='greater')

print('stat=%.3f, p=%.3f' % (stat, p))
# Out:
# stat=44.000, p=0.053

# %%
# Interpretação

alfa = 0.05

if p > alfa:
  print('Não rejeita-se Ho')
else:
  print('Rejeita-se Ho')
# Out:
# Não rejeita-se Ho

# %% [markdown]
# Comparando com valor de referência utilizando boxplot

# %%
from matplotlib.lines import lineStyles
import matplotlib.pyplot as plt
import seaborn as sns

sns.boxplot(retorno_invest['Metais'])
plt.axhline(y=mediana, color='red', linestyle = '--')
plt.show()
